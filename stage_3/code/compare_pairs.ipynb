# %%
import pandas as pd
d= pd.read_csv("sample_pair_iter_1.csv")
#print (list(d.columns))

pd.set_option('display.max_colwidth', -1)

d[['ltable._id','rtable._id','ltable.Name','rtable.Name','ltable.ReleaseDate','rtable.ReleaseDate','ltable.Director','rtable.Director','ltable.Genre','rtable.Genre','ltable.Runtime','rtable.Runtime']]
# Out:
# ['Unnamed: 0', 'ltable.Certificate', 'ltable.Director', 'ltable.Genre', 'ltable.Grossing', 'ltable.Name', 'ltable.Rating', 'ltable.ReleaseDate', 'ltable.Runtime', 'ltable.Up_System', 'ltable._id', 'rtable.Certificate', 'rtable.Director', 'rtable.Genre', 'rtable.Grossing', 'rtable.Name', 'rtable.Rating', 'rtable.ReleaseDate', 'rtable.Runtime', 'rtable.Up_System', 'rtable._id']
#     ltable._id  rtable._id                             ltable.Name  \
# 0   2406        698         The Kennel Murder Case
# 1   1308        2140        The Howling
# 2   1129        2665        The Sugarland Express
# 3   2531        2133        The Adventures of Prince Achmed
# 4   1483        2107        The Color of Money
# 5   129         2580        The Matrix Reloaded
# 6   2161        2151        The Adventures of Ichabod and Mr. Toad
# 7   196         2771        The Bourne Ultimatum
# 8   2392        953         The Ladykillers
# 9   1561        2102        The Cranes Are Flying
# ...
